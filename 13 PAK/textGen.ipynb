# %%
import re
from collections import Counter

import codecs
import numpy as np
import gensim

import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from tqdm.notebook import tqdm

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
with codecs.open('plut.txt', encoding='UTF8', mode='r') as f:    
    raw_docs = f.readlines()

# docs = [re.sub(r'[^А-я ]', '', doc) for doc in raw_docs]
docs = ' '.join(raw_docs)

# %%
def text_to_seq(text_sample):
    char_counts = Counter(text_sample)
    char_counts = sorted(char_counts.items(), key = lambda x: x[1], reverse=True)

    sorted_chars = [char for char, _ in char_counts]
    print(sorted_chars)
    char_to_idx = {char: index for index, char in enumerate(sorted_chars)}
    idx_to_char = {v: k for k, v in char_to_idx.items()}
    sequence = np.array([char_to_idx[char] for char in text_sample])
    
    return sequence, char_to_idx, idx_to_char

sequence, char_to_idx, idx_to_char = text_to_seq(docs)
# Out:
# [' ', 'о', 'е', 'а', 'и', 'н', 'т', 'с', 'л', 'в', 'р', 'к', 'д', 'м', 'у', 'п', 'ы', ',', 'я', 'ь', 'з', 'б', 'г', 'ч', 'й', '.', 'х', 'ж', 'ш', '—', 'ю', '\n', 'щ', 'ц', 'э', 'Н', 'П', 'В', 'О', 'К', '!', 'Г', 'А', 'С', '-', ';', 'М', '?', 'ф', 'И', 'Т', ':', 'З', 'Д', 'Е', 'Э', 'Б', 'Р', 'Я', 'У', 'Ч', 'Л', '«', '»', 'ъ', '1', 'Ж', '…', 'Ш', 'Х', '2', '9', '8', '3', '0', '(', ')', '[', ']', '4', '5', 'Ы', 'Ф', 'Ц', 'Ю', '6', 'Й', 'Щ', 'Ь', '_', '7', '„', '“', 'e', 's', '–', 'i', '+', 'I', 'n', 'a', 'o', 'r', 'X', 'c', 'u', 'v', 'm', 'l', 'ё', '°', 'g', 'h', 't', '*', '/', 'w', 'b', "'", 'Ъ', 'D', 'R', 'd', 'H', 'f', 'S', 'K', 'O', 'T', 'p', 'P', 'C', 'y']

# %%
SEQ_LEN = 256
BATCH_SIZE = 16

def get_batch(sequence):
    trains = []
    targets = []
    for _ in range(BATCH_SIZE):
        batch_start = np.random.randint(0, len(sequence) - SEQ_LEN)
        chunk = sequence[batch_start: batch_start + SEQ_LEN]
        train = torch.LongTensor(chunk[:-1]).view(-1, 1)
        target = torch.LongTensor(chunk[1:]).view(-1, 1)
        trains.append(train)
        targets.append(target)
    return torch.stack(trains, dim=0), torch.stack(targets, dim=0)

# %%
def evaluate(model, char_to_idx, idx_to_char, start_text=' ', prediction_len=200, temp=0.3):
    hidden = model.init_hidden()
    idx_input = [char_to_idx[char] for char in start_text]
    train = torch.LongTensor(idx_input).view(-1, 1, 1).to(device)
    predicted_text = start_text
    
    _, hidden = model(train, hidden)
        
    inp = train[-1].view(-1, 1, 1)
    
    for i in range(prediction_len):
        output, hidden = model(inp.to(device), hidden)
        output_logits = output.cpu().data.view(-1)
        p_next = F.softmax(output_logits / temp, dim=-1).detach().cpu().data.numpy()        
        top_index = np.random.choice(len(char_to_idx), p=p_next)
        inp = torch.LongTensor([top_index]).view(-1, 1, 1).to(device)
        predicted_char = idx_to_char[top_index]
        predicted_text += predicted_char
    
    return predicted_text

# %%
class TextRNN(nn.Module):
    
    def __init__(self, input_size, hidden_size, embedding_size, n_layers=1):
        super(TextRNN, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.embedding_size = embedding_size
        self.n_layers = n_layers

        self.encoder = nn.Embedding(self.input_size, self.embedding_size)
        self.lstm = nn.LSTM(self.embedding_size, self.hidden_size, self.n_layers)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(self.hidden_size, self.input_size)
        
    def forward(self, x, hidden):
        x = self.encoder(x).squeeze(2)
        out, (ht1, ct1) = self.lstm(x, hidden)
        out = self.dropout(out)
        x = self.fc(out)
        return x, (ht1, ct1)
    
    def init_hidden(self, batch_size=1):
        return (torch.zeros(self.n_layers, batch_size, self.hidden_size, requires_grad=True).to(device),
               torch.zeros(self.n_layers, batch_size, self.hidden_size, requires_grad=True).to(device))

# %%
model = TextRNN(input_size=len(idx_to_char), hidden_size=128, embedding_size=128, n_layers=2)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2, amsgrad=True)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, 
    patience=5, 
    verbose=True, 
    factor=0.5
)

n_epochs = 50000
loss_avg = []

for epoch in (pbar := tqdm(range(n_epochs))):
    model.train()
    train, target = get_batch(sequence)
    train = train.permute(1, 0, 2).to(device)
    target = target.permute(1, 0, 2).to(device)
    hidden = model.init_hidden(BATCH_SIZE)

    output, hidden = model(train, hidden)
    loss = criterion(output.permute(1, 2, 0), target.squeeze(-1).permute(1, 0))
    
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    
    loss_avg.append(loss.item())
    if len(loss_avg) >= 50:
        mean_loss = np.mean(loss_avg)
        print(f'Loss: {mean_loss}')
        scheduler.step(mean_loss)
        loss_avg = []
        model.eval()
        predicted_text = evaluate(model, char_to_idx, idx_to_char)
        print(predicted_text)
    
    pbar.set_description(f'[Epoch: {epoch + 1:2d}] loss: {loss.item():.3f}')
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# Loss: 3.066613554954529
#  подни отоли полосто стостони косто но в онол водо вони сно сто вень но посто но потой столи поло в болол восков полом черел ете отоли постато посталь ваве токат в полак кене востосто по ноза помони по
# Loss: 2.5554444885253904
#  тора не поредерени столы сторо бо сторо востольни в бо кодолье тольно столеми столой содать на сколости в сто отсто полали больи в домсти поредне сторо породить ны полити порости поромали сторал на и
# Loss: 2.3478259372711183
#  попотомо на полого и стали и стала ворутно породи и в долять и на в подного со востали и на полодельно вожно отраники соверенно пополомом на стором в просте в сладали востелько потором половали на под
# Loss: 2.2132659482955934
#  баланов и полодовали в полодить с долкам достров стали от долта приставший на полодели на стровало в стали на полодельно на простых и от ветров состровали в нестом по на канных но стровал от на было в
# Loss: 2.1136361169815063
#  постельно с в порого с поровенных и по от на полодно подновались отровили на стали на подин и на на пожели стали которого на сторотели в стором следова в уже с полудали осторовались с подного не под в
# Loss: 2.0372544622421263
#  верный с постерева не который до стали предведно постать не не вода в показал остали не деревенно стретили в стали на делов в поднимать поляда и поднять не стали они от поляние и поляния и по расседил
# Loss: 1.984302442073822
#  собаки который простой деревались до воды в положение призно в подов водом которые стали полода по вода полова не не воду в продолжать в полова и остал серы остала северно на оставил в верных только н
# Loss: 1.9435077714920044
#  от до деревали подняли на на по пришли положение водой все вода на поднение подостова водом воды с сторонова и и подняли которые подоворовали с востородил от собаки присторовали в должно поднивали мож
# Loss: 1.8921971201896668
#  и поднимали с временно с больше в водили собаки поднял поднял до кракные полоса и собак, на поднял в глубь и заправились в немного ного по положили с оставил Каштанов и следовал по не полодники поднял
# Loss: 1.862456612586975
#  ростения с которых положивали на обрывались в под стоянки и сторонов были при и было образили на семеровали и выстрели и поднялись и на северных по обедили в стольно по недобогами и последние дело не
# Loss: 1.836232566833496
#  собак старая на оставил Каштанов. — В нем подорта и подненно последние поднял на северные стали в подняла старали в середовали могла в остал оставление с на не полярная стороны и произволи полосил Гор
# Loss: 1.8141372323036193
#  подобной полянов только только поверхности по полоса от него воды сторонов.
#  — Не поднялись по удали и подняли по поляну откудины и подобного вы выставил оставили старались подняли в получае странных
# Loss: 1.799085431098938
#  на не поляна поляну, которые положение и последние только не подняли полова с возврасили в своей в которые в середования в землянки в которые провершина и поднял в остороны на не сторона на получили в
# Loss: 1.7792159485816956
#  северные меньше из последние прибавались берегу последние все подняли с запасали все собакой поднять спуски последними на полоса и последние восток на следовать только стали последней видели собак с н
# Loss: 1.7608892011642456
#  не полоса половина и подобными без которой получает скалы, и воздуха в водой и высокими поднимать вернуть в полянами, кости в острова и подняли в положили в половины и северов и в несколько воздух по
# Loss: 1.7497237849235534
#  который показал Горюнов, — приблизились показал Ордин в деревья и прибавил Горюнов.
#  — Поставили все они присоление с ними светил у нас под поднимались положение воды и подняли в немного прибавил Кашт
# Loss: 1.718204162120819
#  на северной на по воды от несколько поднимались постепенно под на поднимания северный только от поляну по вернули в стороны поднял в раздали продолжали на не поднялись поднялись на положение по него н
# Loss: 1.7246422100067138
#  на воздем и поднялись в собаки поднялся по половины успели в поляну и в обратно не все по другой полость по разверя в колок в вода — поляну, которые очень по открытый проможить столько на оказали свое
# Loss: 1.7095307326316833
#  образовали в него собаки и собаки в верхните собак спустились в несколько не поднялась доставления по следовательно было при верхнего приближать собаки спокойно в сторону и воздухе полос от северов и
# Loss: 1.7049455523490906
#  на полоса по нее старый и поднял на странными они половины образовали от нему, на потому на другой поднимали было стала странным на положденных на следовательно пробывались в туман с может возразов и
# Loss: 1.6979360795021057
#  даже принялись в положили и сторону по несколько может было и поднимались от несколько пришлось в середения в середение, нас и последней и положили в огрании и в северной уже на сторону протом на оста
# Loss: 1.6960383915901185
#  потому что на стало в поляну острова от этого странного потому потому подолным вода вернули в которому поднималась на воде и поднималась в стороны с глубине получание в противольной воды в потому на с
# Loss: 1.6797771453857422
#  северного выстрелов и вернулись по недолжно была своей по сторону и с нас на него собака в стал пододомнимать и по приблизились с надобно и поднимать в этой стала поднялись с получаем в северного до с
# Loss: 1.6708892321586608
#  северной последние онкилоны и и привет своих стоял по которой не странное и последним они последней восток на северной собак полоса по сторону и последний последние местами от воздухе было последние п
# Loss: 1.6707681703567505
#  него от тополовик и сторона последней по удара в которые последний полоса и столба в которые остров и на возможно половины восток последние полоса по восток, что в должны было остальных подолнительные
# Loss: 1.6605985927581788
#  оставили становились на северного положение и последние собаки в сторону на северного воды ледяные острова и в сторону и стали в показали на берега и по поднимались в нем показали на обрыва и сторону
# Loss: 1.655464162826538
#  половины с собак на северной оставил Горохов, они полось от рассмотрев от ними под которые поляны под востокилоны на острова по вода и не положили все показались с вода стал в рассмотреть на него на б
# Loss: 1.6410418581962585
#  себе стали поднялись на столбу, поднимались с нему не вода и достали в другие крупные в деревья к нему собаки которых последние которых полоса приследились в нем стали также по несколько выше берегу и
# Loss: 1.6436421942710877
#  восток положили за нас и поднимались на северный на подняли в странные море было поднялась собаки подняли в которых остальные подняли собак сказал Горохов.
#  — Ну и в воде подобно на северные половины,
# Loss: 1.639046185016632
#  не стали на подниматься и приняться и странной остальных в продолжать приследовать только собаки и одной полоса также по него от восток и по толки под которого поднялся на полоса солнце и глаза с нее
# Loss: 1.6332186484336852
#  полости на подобно в стороны и полости и расстояние и по время все половины и полосы с разведа на северного собаками приходить по ним продолжал собака от севера и с нас и участников и подобно было на
# Loss: 1.6337474226951598
#  последний последние образовали на северного собак положили образовали в тем и на ветров в стороны по водой и поднимались на северного из под возле поднимали все пробирались на северной положили положи
# Loss: 1.6269129920005798
#  собак и раз и и собак после поставили подняли в котором под несколько промолодов в котором по следовательно и он по время по поляне в несколько выстрели и добычами и поднялись на полоса и потому что н
# Loss: 1.625257933139801
#  должно было стороны на от нем которого он собак и подняли в вода половине по полости подножия подортовали к нему воды, поднялись от него под ними с последний поднимались на обрыва и поднимавшие должны
# Loss: 1.6203381037712097
#  представляют на вернулись последние кроворилась на собиралась на образовали вы не на северного берега и высокие при полянов. Они онкилонов и по поляны не поляны и выстрелов на котором положили в ней п
# Loss: 1.6171734523773194
#  северного последней возвышили в землянки, поднялись от север и от перед нас и в поляны по следовательно и положение с другие затем и был в обратно положение от должно было они в котором в треть в стор
# Loss: 1.6094300055503845
#  собаки по вода и в это вода и все от разных под согласились на своему по расположил Горюнов. — Не на полярным получили в попадались на северной полярные противольно по них в стороны и полоса выстрелов
# Loss: 1.6034544014930725
#  не продолжали простал в полярными против принялись на поляна с надели в сторону последней стали к ним на только простали со сторону не поляны и потому поднимались с ними и с него с только не собака по
# Loss: 1.6044290614128114
#  северные положению в постепенно под нас в воды в положение собаками и не положение и воды пришлось последнего в вода по которых последнего сторону стали собаки на северный место и подобной столько в о
# Loss: 1.6106934070587158
#  сторону и пришлось по север по сторону и стороны с востоку подности и в сторону в самой полость по полость и самой полость и собаки по свое стали с другой на северной предположения по него обратили с
# Loss: 1.5992779040336609
#  себе поднялась в северной полоса полоски от несколько только сторону собаками поднимались на ночь и затреть и поднялись в положение с него поляну с них высокие северного положили на северной просотки
# Loss: 1.5987905073165893
#  Вернул со следующий столенным и собаки и стороны и стояла к ней выстрела и может быть на остальные стороны и странным стояли в северу от образовать собаки в стороны от места и поднял подобности в поля
# Loss: 1.5938137984275818
#  собаки стал на северо-восток стороны и подняли в одной собаки воздух метров почти на северной поляна по сказал Горюнов и поляну и постепенно поднимали на стороны которого на местами и на северной поля
# Loss: 1.5968860363960267
#  при не в этом от несколько по воду и на северной вершины и все стали подземные местами и в водой с северной поляны, и были не странный поляна не поляны в носильной странный стали на ней по временам пр
# Loss: 1.5762533092498778
#  берег по поляны и поляна и собаки с поляну по несколько поляна в такой десять в полоса и полоса поляну и полосе на остальные собаками на ветра, в положение на долины и оставили на остальные приблизили
# Loss: 1.5965938782691955
#  востоке и дело в собой и стояли на приметров и стоянки, но по половины и собаки и высокие костер и вернением в своими собак и оставили в поляна и собаки не могли воды, поднялись в двух склоны, и в это
# Loss: 1.5836410737037658
#  которой не поднялись в воду, под стояли вода подобность разведа, на северо по несколько положили с них в стороны и сказал Горохов подняли в сторону с подниматься в воздух под нас и открытое или на ней
# Loss: 1.588850917816162
#  только подняли в поляну, поднимались на нас присели в стороны и поднималась в воде, и по которой стояли на немного десятки обратился с другой поляны и стояли подножия на северной в стороны от следы по
# Loss: 1.579696900844574
#  восток и высокой поднялись в северного стороны остановился не собаки остальных собаками и собаки по стойбища и последний стал на положение воскликнул Каштанов и старой постепенно полезной произвели в
# Loss: 1.583486349582672
#  северной открытой сторонов и словно на поляну и в которой возможно на меня в ней последний на северной стороны и в стороны обрыва и поднимались на острова и при на север на водой и прошло на север и п
# Loss: 1.5646336913108825
#  сообщить в двинулась в поднимались в полунерали от удалось в несколько разведки поднимались в несколько предположил Горюнов не поляны на положительных в выстрелы в движение в несколько на поляны в сто
# Loss: 1.5720808577537537
#  северной странные вода и приближались до стороны на несколько поляну и последний сторону поднималась на северные становились в ней приближалась возвращались на север и продолжались на северной последн
# Loss: 1.5755628299713136
#  оно оставили в обратно с объяснили его вернуться в последней направились в море в стороны на поляны и продолжали вы поляны. После по расстоянии стал за которой по сторону подняли на север и привез был
# Loss: 1.576836404800415
#  положили собаки на северного возвращались от него на водой и за состоянии и слова стали воздухе половину, но высокой сторону оказалось на сторону и от слова и последним стали положили под водой и стал
# Loss: 1.5671615815162658
#  по полярных только на несколько на северной собак, они остальных собаки и на поляны и остальных которого они сказал Горохов в несколько выстрела, на нескольких и слова которых слова и сказал по воду и
# Loss: 1.5711111974716188
#  воде в сторону, по вода и последнего не выстрел и вернулись в полосы в которой стояли от стояли в сторону и поднялась в сторону и оставили поверхности в полосы остановил собаки по несколько берега и в
# Loss: 1.5669426155090331
# Epoch 00057: reducing learning rate of group 0 to 5.0000e-03.
#  на которой волнули в северной стороны подножия только за нее собаки странных половины, — заявил Каштанов в стороны от метров поднимались в раздали от собой стороны в которой от место и поднять на севе
# Loss: 1.5353780269622803
#  такое сторону и по отдельные которого по поляны в сторону подобно в носом и поднимались в котором на охотников и воды в сторону и поднялись на сторону в какой-нибудь от травоядно с нас и в обратно и с
# Loss: 1.5338458251953124
#  полосе со своей сторону и с остальных собаки северной положили бы воде с добычу с которых на половины и на северной поляны, поднималась от собаками, чтобы принял возна и погрузила в которой по леса, п
# Loss: 1.5319110727310181
#  положение в такому через несколько сторону, поднял свое было воды до положении на воздух поднимались на воду в поляны и в сторону, под половины в этом присели поляны, они последнего поляны и поднялись
# Loss: 1.517836365699768
#  поляну по которой в собаки стало продолжали на северу и поднимались до получили в сторону с последней поляны и поднимались со склоны и все поднялись от них в несколько части и последней поляна конца о
# Loss: 1.51497456073761
#  четырех не собаки подняли на положении странных положение в сторону и стороны на положение в сторону и приставили на северу и подняли на положение поляны, и на север и подняли по полосы с восток и пот
# Loss: 1.5213747715950012
#  собаками по стороны и скоро можно было на несколько подняли положение и по представляла в половины подобно в него от полосами и полосами и половина не положение от несколько и они были от несколько тр
# Loss: 1.525130410194397
#  собаки на онкилоны с положили от после белые полосы на северной стороны с собой которого не было в это возвращались от местах на обрыва в расстояние в поляны и поднялись на северной собаки с полосы он
# Loss: 1.5225755214691161
#  полоса последний из северной после при костра и под вода в сторону под воды с ним и до воды на северной стороны не не последний продолжать в сторону подниматься на одной восток и по руках и при не про
# Loss: 1.5201974177360535
#  половину которого возвышали по вода со своей последней подняли в сторону и по ней подножия поляны и положили своей принялись на положили в трещины уже подняли в образовали на полосы подняли на север,
# Loss: 1.5123395371437072
#  которой полоса поляну и после стали стали становились в образовать в образовали слова на воде и произвели стали подняли собаки с обрыва и потока в котором вода на воду в поляну и под стороны и в полян
# Loss: 1.51274676322937
#  уговорить в треть и воды, выстрела стали в обрыва в течение востоке и остальных последние на поляны, которые при водой и подняли собак, простор был на великов, по ним и поверхность совершенно выстрела
# Loss: 1.5103355026245118
#  дальше и в реки, которые выстрелов и вернулись в сидели в одном затем по расстояние на ней на север, не было пришлось утесы поднялись в сторону не стрелялись на несколько последним произверей в сторон
# Loss: 1.5021990871429443
#  только поляны не подниматься на полосы были поднимались на воздухе и на нас последний подняли в сторону и остальные последний время на обрыва и по временам подниматься и подняли в лесу и поднялись в н
# Loss: 1.5144950079917907
#  ваши показалось в достаточно под полоса положили от своей стороны и подняли собаки по полоса и рассказал в сторону на восток подняли различной стороны и головой и остальных поднялись в стороны положен
# Loss: 1.5056710433959961
#  при все половины продолжали дальше не ударом подняли по воде на поляны и поднималась на подножия от немогнуть и положили восточной поляны, последней стороны со своей тундре прошли темных положение и в
# Loss: 1.5195099520683288
#  мы не поднялись в северу по поляну и последней положили своей вода, они стали сторону поднялся от несколько поднялись на положили видно было положили в образовать в поляны от северной стороны с положи
# Loss: 1.506062068939209
#  положили на северной и поднимались в сторону по полость на север поднялись в образовали в сторону и придется последний от них и подножия при должны были странными в которой подножия положили до себе н
# Loss: 1.5014055037498475
#  собаки в стороны подняли под место на образовали по раз по место и последнего подняли их подняли свое гора на которой вода собака и собак и в сторону и подняли в несколько придется только произвел пос
# Loss: 1.504393639564514
#  половины и поднялся в собак поднялись на положении в половины и на берегу поднялись в сторону и поднялись на северо-земленный поляна и на северной на север, которые поднимались в этот обратно и поднял
# Loss: 1.5014395713806152
#  совершенно поднялись в этом последние стороны поднялись в землянки и гора и на северной сторону по стороны и остальные положили на северной поляны и восток и последние стороны по этому породы в полосы
# Loss: 1.4948680472373963
#  породы и поднялись в несколько отдыхали по лес с нарты на него по полость в воду, на него положили в глубь стало в которой сообщили в поляну и на которых словно собаки по следующий столбов от вода под
# Loss: 1.5102452969551086
#  под самого вода и по всем половины собаки под вершины подняли в своей на сторона принесли в него образованием в том стояли на своем странных поднимался по ней половины собаки на только по ними в сторо
# Loss: 1.5046871542930602
#  поляну должны было стали на которой на только из в руках и от стороны с нарту подобно продолжались в воде в только полосы в следовательно и на стороны и случае в недалеко должны была в море обратно по
# Loss: 1.5026345586776733
#  воде и поднялись в обратно и которого не собаками и остановились в самой поднялись в образом поднять положили до берегу были они убежал в сторону и последний на север, которые поляны и поднялись в сто
# Loss: 1.5014200472831727
#  последние стояли стали на поляну и подобного воды и подножию поляны и поднялась от которой вероятно и поляны, они приследовали и поднялись в котором стойбище, потому что встречали протяжение и подняли
# Loss: 1.4980959129333495
#  и поднялся поднялся в полосы от которому метров по стороны после в сторону на север, поляне после последнего сторону и водой последнего последний последний стороны и только поднимались в том и следова
# Loss: 1.5052489757537841
# Epoch 00084: reducing learning rate of group 0 to 2.5000e-03.
#  присловились в котором не открытие в обрыва, за ним и совершенно половины и по увидели свое полоса стояли по стороны и по две и на северу от них на своему стояли в несколько леса на острова последние
# Loss: 1.4891115140914917
#  при возвышенности и поляны от несколько подобно после уже на северной стороны в сторону в поляны в недобности и последним стороны на трудно на север, которые положение от местами и стал следовательно
# Loss: 1.4756935048103332
#  собаки под нас и и стороны уже на недобрались в сторону в которой поляны. По воду и выстрелов в несколько открытие в получили привезти и половину и поднять своих возвращались в воду, вытащил в которой
# Loss: 1.472883508205414
#  пришлось поднялись в образовали в глубь собак поднялись к которому подняли собак и от восток по временам на нем поднялись в сторону и принялись по полосу должны были были по поляны и поднялись в стран
# Loss: 1.474319577217102
#  добраться на север, которые воинов и приступили в остальные полоски, по поляну и на поляну и выстрела и принял на несколько подножия собак по поляны, который последние на ночь в сторону в своих по бер
# Loss: 1.4779730868339538
#  поднимались в состоянии и высоты и вернулись в него в сторону в двух он подняли на полость и поднимались в приблизились в другом собак и последний и поднимались до воду, которые поднимались в это врем
# Loss: 1.4806332612037658
#  и на северной провизии и поляна и воды, — предложил Горюнов.
#  — Вы все продолжали под открытой стороны подняться в сторону и обратно и подняться в обратно, что вернулись в сторону на северной пробирал
# Loss: 1.4786818027496338
#  половина на север, что на северо-предненный на север. В половины и поднялись в которой породы и обратно с которой поднимались до ними в привезем поднялись на нем поднялись в половиной подобно положени
# Loss: 1.4828338932991028
#  можно было стороны и последней положение по полянах на половине и подняли по поляны в сторону последней на руками в сторону и пор на северу и последней поляну и подняли в своих прокрасно высоких получ
# Loss: 1.4792975687980652
# Epoch 00093: reducing learning rate of group 0 to 1.2500e-03.
#  собаками и стояли в поляны мелких собак в нее сказал на востоке от сторону и собаки под возле поднялись на положение последних по полосы на севере и поднимались под водой и собаки с него оставили в не
# Loss: 1.4810100173950196
#  также уже на острова. Но в котором последние поляны и подобно не только обратно на северной выстрела все потом в полосы выстрела на северной день стал больше не подножия поляны в несколько море в кото
# Loss: 1.4647536182403564
#  от полосы от несколько которого и последнего серы и привлекали в одном поляну с небольшими стрелять по стороны не проникнуть в сторону и после их после поляны и от половины и поднялись в сторону и под
# Loss: 1.466499903202057
#  маленьких на котором стали попадалась с места и поднялись до водой и поднимался собак и все положили на ней поднялись и в три выположение в сторону с собой совершенно поднялись до воды и погибли с сов
# Loss: 1.4743528008460998
#  при они постели в которой высокие проникнуть попадались на восток и он под направление и трудно полосы на север и по собакам и проникнуть от костра, по несколько положением при показали поднялась и по
# Loss: 1.466222915649414
#  начала из восточной стороне подвигались на север по которой принесли на север. На обратно и поднимались в землянки, которые последнего воде, и вода от них и делать в стороны не собаки подняли в сторон
# Loss: 1.468365204334259
#  половина по открытых положение и в положили отступали с поляну и собаками и собаками и поднялись в стороны выстрела и пришлось ответил своей привернения по поляны и последний в одной снега и на север,
# Loss: 1.4694359660148621
#  на того в положении и понимать по открытия и под воды и показывали в обратно от несколько море с полосами и положили под возможности противоположного собаки от моря и подняли собаки могли состояла на
# Loss: 1.4649550247192382
# Epoch 00101: reducing learning rate of group 0 to 6.2500e-04.
#  и последний на север и поднимались на север, но принял странные положили в каким признак и подняли на сторону, поднял остальные от дерева и подняли в крупные половины с воздух с поляны у них последней
# Loss: 1.4597274565696716
#  мамонта с недобелические весла, поднимались не подняли самого полосами и последних положение по стороны подняли его подобно не подняли остальных собаками подняли на несколько поляна и поднялись в тунд
# Loss: 1.4549316263198853
#  при воздуха под несколько поднялись в сторону и в какой-то запас собаки на север. Но это было последние при своей полосы камни поднимались в какой-то подняли случае поднялись в стороны стоял в полярны
# Loss: 1.451354284286499
#  полосы в которой в полосы и показались на половины и на одной вершина поднялись в положили место от несколько одной положили в течение на другой поляны в сторону и приняли поднялись и высоких поляне о
# Loss: 1.4685326623916626
#  при воды и в сторону и после показалось в нее и поляна от собаками и собакам показались под темно-бурого собаки были делать и потом он на которой подняться на воде поднялись и спустились в половины и
# Loss: 1.4541719150543213
#  собаками по воде, на север, которые последние стороны и открытия с полоски и полость по сторону поднимались света подножия воды представляла подняли в глубине которого в сторону и поднялись на поляны,
# Loss: 1.4537473797798157
#  самого при воды и проведали на север и поднялись в полосы и достаточно поднялись на него и стороны и поднялись в сторону и под противоположного обратном время под нас и последнего в сторону в полосы в
# Loss: 1.4531900787353516
#  северном полость от него было половины в окраины в полость и выстрела совершенно выстрела и последней стороны и пришлось подняли в обрыва, под поляны и на полосы и стороны с ней поляны в сторону подня
# Loss: 1.4705393481254578
#  на северной вода уже поляны с трех полосами, после поднял места и отстоят собаки подобно при уступами и на север, которые половины и на восток — восточной воды в несколько на север, на север по образо
# Loss: 1.4594115591049195
# Epoch 00110: reducing learning rate of group 0 to 3.1250e-04.
#  полости запас возле поляне совершенно поднялись в сторону и показались на воду, которые воскликнул в стороны подобно в достаточно и последний вода последний и в сторону и при не провели по сторону и п
# Loss: 1.4647266340255738
#  берега от несколько положили в сторону по своих северной полосами и последний ветра от открытия в поляну от которых последней полосы подняли вернуться в небольшим и получил своей подняли все поднялся
# Loss: 1.457258563041687
#  себе поднялись на положение от нас подобно подняли на поляну в поляны и пришлось подняли в окружили по открытие на север, на несколько последние стены в полосы с место и подняли подняли в котором откр
# Loss: 1.4606546998023986
#  восток собак на север, не обратно по сторону и под другой последний в сторону и приветствовали по стороны на нем получить к судно и оставленные сторон и поднялся и поднялись на половины подобной воды
# Loss: 1.4543356585502625
#  материка. На севере в сторону проводников, и обратно на несколько следы в сторону и поляны с горизонта, на поляны проводников и при своей странных поляны и продолжали собак и последний полоса водой. В
# Loss: 1.463961672782898
#  последний в него по стороны и добыче на которой не последнего стороны с поляне поднялись в полосы на месте на полосы в вода в положили направлением которого через льдов в сторону и которого воды и на
# Loss: 1.4532406091690064
# Epoch 00116: reducing learning rate of group 0 to 1.5625e-04.
#  сторону и поднимался только на половину и на первые оставили на север и в сторону и не последней не стали последний воды, и поднялся в странами, на своем на север от него поднялись в поляны и в сторон
# Loss: 1.4534304976463317
#  собаки не совершенно пришлось поднимались в полосами и пришлось поднялись в своих последний восточной полос дело и поднялась на северной полоса последние представляла так и на север, оставил собаки со
# Loss: 1.4522346949577332
#  представляла своей прокатился и поднялись на ночь на север и поднялись в несколько можно было поставить в это время на стороны и принялись в двух море, — заметил Горюнов.
#  — Не было не поднимались по
# Loss: 1.46181542634964
#  покрытым подняли по своим половины на поляны, и не случае собак и только половину и в стороны и поднялись до половины под собакам. На положили от поляну, подобный стороны и следовать в сторону подняли
# Loss: 1.4597224879264832
#  и довольно восточной поляны они стали поднимались в этом поляны и пришлось подняли из поляне последней отверстие с одному пришлось по море в него из месте, пока можно было на север. Так как выстрела в
# Loss: 1.4531890869140625
#  очень со всех странные в течение случае и последние сторону, больше и с образовали по стороны и подняли на север и собак и под несколько не принять от водой и положили в своем подняли на север по трет
# Loss: 1.4463065099716186
#  северной колосный положили в котором последние воды на северного вершины и протяжения с ними и которого полосы в сторону, чтобы поднялись и поднялись поднялись в какой-то оставить поднялись в землянки
# Loss: 1.4577900385856628
#  представляла местах в поляну и уже воины и не поднялся и поднялись на стороны в сторону и последние следующий полосами в воду, подняли себе полоса выстрела по расстояние с разных собаки поднялись в по
# Loss: 1.4546862769126891
#  поляну и от половины на севере красными последних открытие с собой на восток и погода только просто поляны и на нескольких отрезанием от полосами и последний в котором стояли в одной острова и по поля
# Loss: 1.4517443680763245
#  и принялись в нее и поднялись в несколько разведчики в поляны, и последней поляны и последний из стороны с полосы в несколько местах и под водой и продолжали собак и пришлось за ним на север, но котор
# Loss: 1.456613359451294
#  головой и подобно собаки не поверхности и половины на следовательно и не подняли по воде и в землетрясение по полосы выстрела запас открытия и поднимались от него потом положению и стояла они странный
# Loss: 1.4486133551597595
#  собакам в сторону и подняли дальше на северной полосами в какой полоса приблизились в какой-нибудь половины с острова и в путешественники в которой поляне подняли волны и поднимались с ними по стороны
# Loss: 1.4501201176643372
# Epoch 00128: reducing learning rate of group 0 to 7.8125e-05.
#  разные стороны и случае и только в половины в него от половину и последние положение должны были последний стороны и поднялись на север, следовательно вы только вернуться на двух стороны и приблизилис
# Loss: 1.4537624311447144
#  половине из них поднялись в сторону все воды от полосы по третицами поднялись в сторону и вода в полосы поднялись в него воздуха на месте и подняли в сторону, чтобы последнее породы в несколько местам
# Loss: 1.4564404225349425
#  при волнами и продолжали с ними и стало доставляли собаки подняли по стороны в которой получили на своему берега и совершенно вода на воду и подняли в которой последние стороны последнего на месте про
# Loss: 1.455736050605774
#  и погода была бы полоса ответил своей поляну, в сторону и не уже с образовали по открытым в сторону с собой возвышался собак и сухаря, словно подняли в поляна половины под собаками и на северной полян
# Loss: 1.4480007672309876
#  которой воды, оставив на северной поляны и подождать в поляну и стали отправились от стены остальные полоса положение от стоянки, он на полоса подняли собак с подножия вода на северной вода на одном н
# Loss: 1.4505132508277894
#  сумерки под собак, оставленные совершенно поднялись на север. Последний и выстрела в полосы и в какого-нибудь от него на севере по сторонам и последние на половине и поднимались в сторону и стороны от
# Loss: 1.4583893847465514
# Epoch 00134: reducing learning rate of group 0 to 3.9063e-05.
#  потом поднималась в больше не поднялись в несколько море. Но на деревьями и высоты на севере поднялись на север. Во время после последних только поляна не могли выстрела и поднялись в полосы и поднима
# Loss: 1.4593998050689698
#  полосы поднялись в русло, которые на севере полосы на поляна и поднималась в нее при случае подняли на северной стороны с ними и стояли по собаками были на берегу местах и поднялись на север, как стоя
# Loss: 1.4567440128326417
#  своей поляны и поднялись в какой-нибудь обратно поднимались в сторону, по сторону. Но пришлось поднялась в своей противоположного половины подняли их до собой и подняли под поляну и от другой и собак
# Loss: 1.4549561357498169
#  собаки и поднимались в сторону и последние воды и со стороны и восточной полосами и заметили в сторону и полосы с ним и собаки были только пришлось принялись на нем от стойбище от стороны подняли в ко
# Loss: 1.4533351516723634
#  оказалось и показались от воды в сторону подстрелить в сторону приближались в следовательно и подобно получили с полостью и не поднялись на поляны и в воду, отдельной полосы поднялись в сторону и посл
# Loss: 1.450752694606781
#  ночлега и из них и положение на поляне в несколько море от них и не было все вот и не собака берега на север.
#  — Ну, на северной на север по которому высокий одной прислушали в которой ответил Горюнов
# Loss: 1.451313123703003
# Epoch 00140: reducing learning rate of group 0 to 1.9531e-05.
#  породу и поднялись на полянах в какой-то все время на обратно на нашей стороны на стороны и обрыва была от которой стали стали подобными странных страны, так как в какой-то закатить на своему породом
# Loss: 1.4575473952293396
#  полосы и скоро нашей положили из водой. После высокой сторону и сказал по временам поднималась подняли противоположного последнего по полосами в несколько стороны по поляны и подобно на север под кото
# Loss: 1.4491840410232544
#  при настоящее в полосы и последний в нее и разразили на север, который пришлось подняли остальных поляну при все подняли на север. Но в которой стали подняться по россыпи и положение и выстрелов и в п
# Loss: 1.451746301651001
#  море от него последний следы в сторону, не подняли в сторону и показались в своему высокий полоса поляну, по соседству становились в сторону в недобности и поднимались в воду и в сторону и собак и все
# Loss: 1.452744312286377
#  положение и в своем только вернулись в сторону и поднимался в стороны и по воде и по плотной положение и в сторону в сторону в образовали от несколько сторонам и стали повернули в другой положение по
# Loss: 1.4505753302574158
#  полосы на обратно, что в поляны, служившийся в сторону в поляну в которой стояли в поляны которого полосы на поляну с нас не подняли собак, подобно в сторону должны были вода оказалось на охоту на сев
# Loss: 1.4484683561325074
# Epoch 00146: reducing learning rate of group 0 to 9.7656e-06.
#  поляны и своей положили собаками и подняли водой, и он продолжал разной последней вершины и образовали по полосе и будет получить за которой от ними и показались все привели на север от них и поднялис
# Loss: 1.447811906337738
#  путешественники должно быть по стороны и поднялись в течение коре с поляны и поднялись в деревьями и повернулись в темно-бурой воды и половины на поляны и собаки от долго и скоро трудно под несколько
# Loss: 1.4529899072647094
#  северной водой. В этой же в сторону. После подняли на север, под подножия поднялись в течение воды. Собаки подняли в трещинами и в сторону и поднимались по поляны, но в высоко должны были вода и по св
# Loss: 1.4501713418960571
#  море и подняли от него поднимались в сторону и стали на север в котором образовали последние полосы в несколько выстрелами. По склон по пропедать собаками и на другой высоких острова и поднялись на се
# Loss: 1.4602846121788025
#  себе образовали в сторону от него подняли своей поляны, поднялся на нем от стороны на сторону, и в воде, не постепенно поднимались на восток от которой было собак, ответил Горюнов.
#  — Не пришлось по н
# Loss: 1.4543463897705078
#  и выстрелили в сторону и под образом и полоса поляны и под воды в то полосы и по льдами и стороны и потому что подняли вода и поднимались от полосы и при поляне на восток и вернулись к обрыва промежут
# Loss: 1.4472138285636902
# Epoch 00152: reducing learning rate of group 0 to 4.8828e-06.
#  море. В половины, которые приблизились на берегу северной поднимались в сторону в поляну ли в просторы под поляну и поднимались на север. Но в воде на поляны при восток и полярной и поднималась поляны
# Loss: 1.4428717136383056
#  продолжали в глубь стороны и подобные получить на восток с полосы на полосами и последний положили в положились на несколько на северной половины были вернуться на нас в несколько вода и полянах в сто
# Loss: 1.4455495929718019
#  восток и после половина на север. Но вы все время по сторону и стороны поднялись в течение было они обратно по стороны были ответили с ними от него поднялись в воде и поднялись на одном половины с мес
# Loss: 1.448698980808258
#  при не последних проникнуть на север, поднял свое образовали на север, но на поляна от поляны в сторону, представляли своих столбов и поднялся просторовали области на север, и высокие стали на север,
# Loss: 1.447960183620453
#  продолжались в сторону и различным и обратно и странно все приследить поднялись по полосы в деревьями, с восток подняли по полосы в полосы поднялись в несколько время по поляну и с обрыва и остальные
# Loss: 1.4552139401435853
#  подняли к сторону по стороны были они своим поднималась в сторону с поляну и при только последней воды, который пойдем на вершины в несколько стороны на острова подобно последний в крупного стороны ок
# Loss: 1.4496470069885254
#  причалить с открытых поляны и подняла на север. Последний и погадались в восток и становился в сторону и под возможности в леса на которой просто поднимались в сторону в сторону и подняли на северо-за
# Loss: 1.4483658814430236
# Epoch 00159: reducing learning rate of group 0 to 2.4414e-06.
#  противоположного на охоту и спокойно и в половиной положение и поднялся, что они не последний рассказал разведения и поляне и под вершина подняли образовали на половине и скоро подножия стороны и воды
# Loss: 1.4535141348838807
#  молоток и принялись за ним и по нас положение от местах и представляли собак, ответил Горюнов.
#  — На которой должны были поднимались на поляну и собаки с одной поляны и стояли на поляны и все остальны
# Loss: 1.4551429557800293
#  и усторожный путь, привязал бы на которой собак и поднялась на восток и подняли в сторону и под полосы и последний на север, и в воду и склоны под берега и поднялся в своей поляны и подножия поднималс
# Loss: 1.4562091994285584
#  и могли быть на севере собаками и поднялись до собаками и в какой-нибудь подняли последний поляны и показались в котором возле было подняли на север. На сторону и на север, но настоящее собак, и собак
# Loss: 1.452490496635437
#  поляны и поднялись на несколько собаками по стороны собаками по стороны по этому поднялись в сторону и поднять свое положение и подняли по несколько сторону с востоке поднялись по стороны не могли был
# Loss: 1.450275330543518
#  восток и последние вернулись в положение было на поляна, под водой и поверхность и попадались в воду, выстрелов.
#  — Как вы стали они подняли в воду от них в полосами и в сторону и подумали и постепенн
# Loss: 1.4518748569488524
# Epoch 00165: reducing learning rate of group 0 to 1.2207e-06.
#  уже вернуться по сторону в сторону и в воду, они не подняли восточной поляны и поднялись на воду, пока подняли на откоду и поверхность и отдыхали их под воды на острова и поднимались в течение противо
# Loss: 1.4521100473403932
#  положили в поляну, на поляне под собак, и последние положили последнего поднялись на север, которые от полость и подняли на север, на северу положение под собаками и подняли на севере поляна и не може
# Loss: 1.4522808694839477
#  маленьких от собак которого не было бы добывали в сторону и проникнуть по стороны на севере полосы метров в первых и не собак по вода и по другой полосы подобно на которых были поднялись на северной п
# Loss: 1.4460327887535096
#  собаки при северной поляны с следующий в сторону и поднялись на острова и последний в полянах и поднялся и в которой моря с востоке продолжались в сторону и натерпелись на несколько местами продолжали
# Loss: 1.4535318946838378
#  при своей полосы в сторону с собой и совершенно стали бы они половину и в треть в леса, по которой собак на котором от нас места и положение от отверстием стороны и остались в разных от противоположно
# Loss: 1.454769093990326
#  собаки под море и последний от стороны поднялись на северной все полосами и поднималась собаки поднялся на полосы и поднялась по уступами и следы и принялись в него последних поляну и поднялись на онк
# Loss: 1.443286805152893
# Epoch 00171: reducing learning rate of group 0 to 6.1035e-07.
#  полосы, поляну и последний и положили в сторону, чтобы отдыхали на севере от нас от полосы и обратно, он подняли в каким на только положение не подняли в воде, открытия подобно выбраться на север и по
# Loss: 1.4463181161880494
#  последние леса. При в воде и собак с ужин. — Ну что же от несколько море от странов, которые стали последний своей поляны ли на деревья и поднимался на север, на которой остальным в которой кратера по
# Loss: 1.4452537107467651
#  сильно пробивались в первым из них собаки собаки в него видно, что подняли к половины с ними и странной отверстием последний подобно за ними с ней по половиной воды и поляны и получили на нашей сторон
# Loss: 1.4560217404365539
#  полосы на северными совершенно собак, пока на северо-после стоял на половины, так как половины и поднимались в полосы в сторону и делать с нас подняться с ними и поднялись на онкилонов и поднялись в о
# Loss: 1.4496284413337708
#  полосами и поднялись в которых полосами поднялись в котором положили в сторону и по воде и собаки в стороны и поднималась выстрела и поверхность подобно на расстилались по положение с одной воды и под
# Loss: 1.4484288549423219
#  промежутки с ними по случае от собак, представлявшие в сторону и поднялись в сторону и поднялись на северной воды на севере в провели в сторону и поднялись в него и последних воинов и меня довольно во
# Loss: 1.4442936158180237
# Epoch 00177: reducing learning rate of group 0 to 3.0518e-07.
#  то не было на поляну, выстрела во время выстрелами продолжались в нее очень полуска от несколько море, которые подняла собакам и получили на север и под поляны с нарты были вода подобно на открытия в
# Loss: 1.4534789061546325
#  самого последний в сторону и потом с ней и поднялись бы они после высоких стояли на северной острова и поднялись в поляны в сторону и поднимался в своем половины от стена и показались по берегу можно
# Loss: 1.4623861265182496
#  воздухе покрыто в течение поляны с обратно и в него стали на собой спасались в полости и стояли на поляны и подняли все воды под ней в сторону полосами последние восточной поляну и на которой на север
# Loss: 1.4496522450447082
#  и возвышался разведение с уступами и подняли на несколько море и принялись в которой поднялась в сторону, которые потом поднимались в нее последним не может быть, в водой.
#  — Но в стороны с ружьем в п
# Loss: 1.4465411639213561
#  мамонта были подняли по открытия в сторону и собаки поднимался на обратно собак на север, которые под нас и оставить собаками и полосами только вода и собаки поднялись в несколько стороны в воду, подн
# Loss: 1.4484291386604309
#  собакам в тундре и в таком поднимались в сторону и поднимался остальные полоса поднимались в сторону и на северу и последний стороны поднялись в него поляны не поднялись в сторону и на восток и поднял
# Loss: 1.4455923557281494
# Epoch 00183: reducing learning rate of group 0 to 1.5259e-07.
#  сильно отряда в сторону в полосами подобно своего не склоне отставил на ней старой на северной породы и под собак, и все поляны и в сторону и приступили и обрыва с острова и в сторону на востоке и все
# Loss: 1.445600163936615
#  при воды на север. Но в которой стали собак на воде на поляны, и в несколько местами в стороны с материка, которые пробивались в сторону и своих поляны и на восток был в сторону и высоком поляну и под
# Loss: 1.4392876744270324
#  которого под своим стороны последней каменного вершины и только на север и поднялись в своей стороны и поднялись в сторону положили в тогда в отверстией в такой поляну в такой полоса на несколько верн
# Loss: 1.4510805010795593
#  полосы от него и расстоянии и женщины и собаки странных стали в полости подобно последний на север в котором солнце поднялись в конце местами на север и подняли подобно собакам в которой обратили приб
# Loss: 1.4505783915519714
#  при половине стали на север, не последней года и на положение, на другой воды и поднялись в несколько поднималась скользили за ним и подняли на нас и на северной поляне и последние от стойбищам и на с
# Loss: 1.4557243084907532
#  положение и на север.
#  — Ну, странный положили к северу и собаки стояли остальные половины подобно подвергались на обратно с образовали по стороны подобно на котором в какой-нибудь остальные полоса ос
# Loss: 1.4550034594535828
#  при полезным помощь, и по воде, и поднялись в несколько вернулись в обрыва по временам странными половины и на север не могли на северной на котором стена и возвращались в сторону подножия поляны и вс
# Loss: 1.4492358350753785
#  порода принялись в него положением к обратно, поднялись в сторону и полосами и приследовать в котором в землянки, на полосы на север, на острова и подняли в полосы и скоро состоянии по собаками и позв
# Loss: 1.4399897980690002
# Epoch 00191: reducing learning rate of group 0 to 7.6294e-08.
#  полосы и по стороны которого колени с другой стороны в двух по воде, на север, и потом собак и сказал принялись по сторону с высокий поляны и на север, по воде и по стороны в этом поляну в своей воды
# Loss: 1.4567945742607116
#  и поднимались от нас на восток и в руками и собак и последних он своей полости на острова в сторону они пришли на север и стали собаками с треть в недолго поляны, под несколько стороны на полости прод
# Loss: 1.456972417831421
#  по северной полосы и по следующий последнего море и последние стороны и поднимали поднялся на нас на которой не на деревьями от них было собаки в сторону и подняли собак по воде с одной время под неск
# Loss: 1.4512868642807006
#  при поднялись в своей стена собаки выстрелили в сторону и поляну и потому что вода на север, с остальные положили свое положили на север, пока не принялись в сторону и собаки от него с северной ветер
# Loss: 1.460629289150238
#  принялись в сторону и половины выстрело в это время в какой-то все воздуха и постепенно было пришлось подняли в полосы за костра и пришлось бы подняли случае воспользовались на север, и затем показали
# Loss: 1.4605477809906007
#  положили в полосы не поднялись на север, и все стороны в половины и последнего великонь на север по стороны с поляны и последнего по части и высокой полосами на нас половины были поднялись на него от
# Loss: 1.4568285298347474
# Epoch 00197: reducing learning rate of group 0 to 3.8147e-08.
#  полосы в него не странным столба и принял своим и поднялись на полосы и по поляне на северной стороны и стали подняли все поляны и поднялись в котором словно на северной попадались в него не было до п
# Loss: 1.4529077291488648
#  положение только на север, под поднялись в своей полости и возвращались в собой и в детей, ответил Горюнов.
#  — Ну, поднял от нас в сторону, на север, и в своей поляны и странный и все положили собаки
# Loss: 1.45257390499115
#  уже стали собаки подобно от него уже скал до северной на север и последние полосы и поднимались сообщить на другой последний странных в сторону на поляны и стали остановились на север. Но не было обра
# Loss: 1.4474906039237976
#  при в сторону и стало собаки поднялись в поляны на нем на северной полосы в одном высокими полосы в полосы, поднялись в течение противоположного на противоположного полосы и в которой последней берега
# Loss: 1.452011547088623
#  на весла и поднялись в которой воды, и вы в которой стояли на север и поднимались образовали не своей открытие полосы в несколько поляну на которой в сторону и подняли на воду и принесли в сторону и п
# Loss: 1.444833929538727
#  при нашим и последние последним подняли местами и подняли на северной и все в котором сорок и поляны и по временам получилась к полости от более поднялся на север, которые заметили от стоянки, под пол
# Loss: 1.4506795144081115
# Epoch 00203: reducing learning rate of group 0 to 1.9073e-08.
#  так как своим последние острова и приняли и подняли собаки поднялись в сторону и от несколько море в сторону в том стояли с поляны под нашим по временам долины и подняли на полосы на последние привяза
# Loss: 1.4512463474273682
#  последних получить в течение воды и все на несколько полостью и принялись в воде.
#  — И не поднялись в котором половины и последние поляны с последние полосы и своим женщины с востоке на полость и по в
# Loss: 1.4579749393463135
#  один и подняли в сторону, который и поднялся на котором поляне под северной день на восток и подняли несколько поляны на поляны с которой стояли в несколько полосами, поднялись в несколько последних в
# Loss: 1.4454678106307983
#  воде в которой сторонам. Они подобные местах в сторону и случае собаки и подняли по поляны. Подобно пришлось от полосами с обратили они долина и последние поляны и поднялась в течение землянки в полов
# Loss: 1.451872637271881
# ...
# Loss: 1.4577161478996277
#  полянах в сторону и поляны на север и только на площадки с него собаком, подняли не поднялись на нем поднялись в которой на север. На острова поднялись на несколько возникают последнего полосами в сто
# Loss: 1.440959393978119
#  после стали получить их собак и стеля и должны были возвращались в которой совершенно потому что в сторону и столба по воде и больше под воды в которой последний стороны и подняли поляны были положили
# Loss: 1.4509996891021728
#  полосы поднимался и подняли только образовал в сторону и последний выстрелов и получили на другой полосами, пока выстрела на северу в положили в сторону собаки стали последним стрелять передние послед
# Loss: 1.452033212184906
#  смотрите с которой воды в половину и подняли на север.
#  — Вот на воду и поднялись на полосы в которой на северной последние острова возвращались в обрыва, который в несколько в образом по половины и п
# Loss: 1.4547597813606261
#  начала и света подобно доставить следовать в сторону и поднимались в котором онкилоны были вода последних положение и расстояния по поляну и последние при не выстрела и подняли последние местах и подн
# Loss: 1.4495466661453247
#  одной полоса было выстрелов и отказался в сторону, и открытия стороны и в сторону, они поднимались в своей полосами и не было выбрали в которой воздухе, он собаки на которой поляна и собаки обратно в
# Loss: 1.4490092611312866
#  северной по собой по полосы и на северу в свое стороны и проведение по нартами в сторону и поднимался в сторону и под нагорожным все странной на север и в воду поднялись и на случае на реки и проверит
# Loss: 1.4548384952545166
#  и поднялись на открытое костров, и в сторону и последней стороны и в сторону под воду, чтобы судно поднимались до воды на поляне, в котором ли после провели в поляны и следы и стояли в него поляны и п
# Loss: 1.4562893581390381
#  при высокий стороны с поляне по своих большой поляна в обратно, что они подняли по стороны не подняли онкилонов в ней с которой на север, словно поднялся в руками, стояли и поднимались в сторону и по
# Loss: 1.448578655719757
#  сильной постепенно под своим колости, которые сказал Горюнов.
#  — Но по поляны и собаки приходилось от него не странии, и все слова и поляны до месте и области приблизились в полосы, открыла поляну под
# Loss: 1.4458026337623595
#  обратили собаки поднялись на другой стороны в воду, подняв в поляны не было вода в несколько собаками, и по собаками и десять и от собаками и поднялись в лесу и собак под образовали восточной голову и
# Loss: 1.4511238837242126
#  мамотельность и подняли оставалось и воды и в разных разведки и поднялись на вершине и на стороны и подняли в собаками и вода и в сторону и положили на него на полости под ними поднимались в несколько
# Loss: 1.453728678226471
#  голову на севере последние сторону на север, и последний острова и подняли попадались за стойбищами на север. Собаки подняли в течение стояли в какой-то он был добыче стали подняли не заметили на кото
# Loss: 1.450524265766144
#  палочки, поднял своей поляны в половина словами по собак и потом поднялись в сторону и принялись в нас воды в сторону на которому поднимались в двух поляны, на которой на востоке своей расстоянии с ле
# Loss: 1.4542205429077149
#  при полезным собаки и подняли местами собак в нем последние стороны с конце вода леса, в день из них по половину до метров и подняли все стороны и старый странных стали открытия в полости по полосы пр
# Loss: 1.4518278694152833
#  северной полоса на север, отстоял с поляну и приветствовали на север, по стороны под гораздо возможности и получили на север и поднялись на месте на северо-восток под собаками и поднялись до насекомых
# Loss: 1.4524584007263184
#  начала собак, оставил припереди на поляне по которых приблизительно последний от колости, но не просто поднялись на нем всего подножия положение в воде, и все последние положение и подняли к ним и пол
# Loss: 1.4513609528541564
#  полосы по половины и попросил он на поляну и на восток в сторону и на него от них в сторону остальными противоположного странных выстрела в треть и не принять на восток и следовать в образом в северно
# Loss: 1.4499611520767213
#  то стороны с поляне и подножия положили в воду и последнего положения от воды по ней полосы по собак, в собой землянки, который последний по которых стали только по полосы подобно порода и последние в
# Loss: 1.4483892941474914
#  полосы и вода и поднимались в воду и не поднялись в поляне при полосы после поднялись на другой стороны и под собой по стороны и поляны и подняли в сторону и стороны на северо-прибавили в сторону и по
# Loss: 1.4590924715995788
#  северной полосы в поляне на северу на север с северной на севере молодые полость и в две подняли на поляны и поднимался по временам после последнего половины и не было выположились в сторону с судьбу
# Loss: 1.4544099760055542
#  и поднимались поднимались в сторону подошли в поляне подняться на север в сторону и поляны и принялись в сторону стали на половина с тем собаки подняли остановились уже не было последние в простором п
# Loss: 1.4473110032081604
#  собаками и возвращением по стороны от стороны и приступить в сторону и стояла по воде, придется остальных полоса и последний полосе было подняться на северной воды и с востоку и высоких при в один по
# Loss: 1.4485418486595154
#  так как вода в воде и стали довольно подняли в расстоянии на нас северной воды с западный предполагают от открытие в полосы и открытие и остальных по обрыва, был за скалами, подобно заметили по развед
# Loss: 1.4542977118492126
#  восток и по воде, что на северу в то привести в поляны в сторону и вершины должно подобно на ночь и приследовать и собаки под нас половины, и выстрелами мелких половины и все подняли поднялась в неско
# Loss: 1.4532893013954162
#  собаки оставили до ним и поднялся по воде и на поляна, который после воды, последние стороны поднялись в этом породы и поднимались в изумлении и подняли в сторону, на северной онкилонов. Но ветер с по
# Loss: 1.4562630677223205
#  собак, но не поднимались на северо-добыча и на поляну и попадались по поляны и пришел в сторону поднялись с нему на севере положение в сторону на которой местах и поднялись по стороны и поверхность и
# Loss: 1.4515326404571534
#  северной на восток по полосы на следующий приветствовали на восток и делать на одном полоса подняли показались в образовали собаки поднялись в поляны в сторону и на несколько стороны принялись в двух
# Loss: 1.4607539415359496
#  полосы. Но по воде и подобно поднялись на онкилонов и темно-бурое вернуться в несколько высокой полосы и во время оставили на северной поляне в поляну и последний собак поднялись на север и от нее пол
# Loss: 1.4519743728637695
#  получить в лесу и сказалось по собак по которой постепенно заставил совершенно на северо-привленных в сторону и подняться на острова на нем поднялась в нем по восточного и полоса перед которых устроил
# Loss: 1.4520015931129455
#  северной поднимались за ним и подняли в которой на другой стороны и помощи море от него на положение по временам на обратно от поляны, которые не представляла собак, и странные воды поднялась и поднял
# Loss: 1.4545408797264099
#  мамонта и подняли обратно последнего поднимались в несколько сторону на котором положение по которой поляны на поляну и приблизились в глубь которого воды, под воздуха и поднялись в одной полость по в
# Loss: 1.4471187257766724
#  продолжался без воздухе онкилонов, удар показались белым из них на север под нас на севере от стороны в котором поверхности на стороны с ними собаки высоты в обратно под воздуха и подняли на половины
# Loss: 1.4512686562538146
#  самого воздуха и подняли по лесу на берегу от него не странных собак и показались в этой воды и подобно на носорога и словами и на которых уступами и собаками и поляны и все положили в двух последние
# Loss: 1.455404748916626
#  своей горизонта и в сторону по половине в сторону и в обратно в ней принялись в обрывы, они стали в полости и под собакам по которой вода от стали на север. После стоял в сторону и поднимался по полос
# Loss: 1.4510024213790893
#  маленькой за ним в это время стояли показал последние отверстие в другой положение поднялись в образовали в обрыва, на несколько стороны и последние стороны и вернуться в сумерки по половины не было с
# Loss: 1.4473286223411561
#  кончили и собаки запасы и по временам поднялись в поляну и последние полосы подняться на север и в которой стороны и в десяти стояли в сторону и собаки и колени по стороны, в течение поднялся на остро
# Loss: 1.452592945098877
#  как и последний возвышались по стороны с остальными поляны в поляны и в сторону, он поднимались в полости с половину открытие и поднимались только не подстрелились в поляны в сторону. Они поднимались
# Loss: 1.4623445868492126
#  полость на севере в воду, последнего в себе половины с восток и поднялись в другой положение и долго серый постели поднялся и поднялись в воде, не поднимались в нем собак, последний своей подвигались
# Loss: 1.4532937335968017
#  положение в третицами от него моря, по которой вода устроить собак по реки на острова от только на несколько которого полосы и высоко поднялись в течение на север, на которой последнего положение и по
# Loss: 1.4552251529693603
#  северной горячим и поляны, и все продолжал в несколько открытие, что удара и подняли по воде, в полость и подняли остальные полосы в своих странные и совершенно причиной и последний своей не поднялись
# Loss: 1.4575084662437439
#  северной водой и обратно по стороны и последний от стали в которой продолжали только не подняли поляне по сторону и постепенно после свои стороны и разведение и костра, поднявшись на северной стороны
# Loss: 1.4600261044502258
#  устья положили в сторону и последние собаки на полосами и поверхности в это время по воде на половины и последние полость и поднялся в сторону и скрытое поляны на восток и последние последний по собой
# Loss: 1.4434499287605285
#  собаками на севере подниматься в две стали оставили на север и не последний от достаточно следующий поляны до несколько стояли на онкилонов и вернулся и поднялась в поляну в своим от стороны, на сторо
# Loss: 1.4499007940292359
#  середине и из поляны и своим слова на ударами и последние на темно-бурого местами и поднялись в полунерами и половины с него положили в воду, которые прислушались на север и поднимались в обе собаки п
# Loss: 1.4540229296684266
#  поляну и последнего из вода и после получить с воздух, которые онкилонов и последние последние запаса на север и вернуться в котором снеговых получили в поляны, пока в полоски и от него по которой в п
# Loss: 1.4556201720237731
#  заставили в которой только на воздух с только по полосы, последние сторону и по стороны и в одном половины и пород в которой должны были на своем на вершины были подножия обратно должны были водой в с
# Loss: 1.4575037026405335
#  разных сторону и поднялись в него от положение на поляны по стороны и от нас поднялись на него тропах с полосы и последние положение в несколько стороны, скалами, пришли на север и подняться с полосы
# Loss: 1.4424723863601685
#  один которого в трещины от полосы и стало в открытое подняли в сторону и принялись по стороны и последние представляла на полудня поляны и стали они на сторону и под поляну и в разных собак поднималас
# Loss: 1.4478373122215271
#  которого обнаружить и показалось по полости с собой по руками на поляне по стороны поднялись на поляну и поднялась и последний последние положением на север, открытое не было в котором при полосы на с
# Loss: 1.4493546319007873
#  под стали в которой тростника подобно подняли по руками с высоко стояли на северной не стали последний воды, последней на них в поляне подобно странным подняли на берегу последние страшно собак, выстр
# Loss: 1.4542255926132202
#  положение пролива в сторону, поднялись в полетели в сторону в сторону и стояли больше подняли в течение половину и на север, которые на севере странные полоска в сторону и поднялись на север. Они долж
# Loss: 1.4502398037910462
#  то подняли последние колости и просто при воды и стороны и с северной полосами по случай по временам представляли собаки подняли на север. На пробивались в полости и на северо-после следы с собой за н
# Loss: 1.4495364809036255
#  дальше и под нас на севере до собой и оставили в которой в сторону, и он на северной гораздо возле когда подняли к нему на северной страны от половины и не поднялись с небольшой полосы по несколько ра
# Loss: 1.458457372188568
#  северной на одной сторону и подняли по месте и стороны и поднялись на семей с половины с восток поднялись на нее стал на друга, на север.
#  — Не было на север подняли на острова в сторону собаки того в
# Loss: 1.4549814867973327
#  доставить по поляна и по стороны были на него в сторону, оставил на полость с востоке может быть в него поднялись в какой-то побежали с северной стороны были стояли на которой получили его в северной
# Loss: 1.454650375843048
#  последний стороны и по сторону и поднялись в несколько поляне с полосы были они поднялись на которой высокой полосами своей стенами с остальными полоса на обратно, что на север и прилежать собаками и
# Loss: 1.4521536970138549
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 37
#      35     loss_avg = []
#      36     model.eval()
# ---> 37     predicted_text = evaluate(model, char_to_idx, idx_to_char)
#      38     print(predicted_text)
#      40 pbar.set_description(f'[Epoch: {epoch + 1:2d}] loss: {loss.item():.3f}')
#
# Cell In[14], line 12, in evaluate(model, char_to_idx, idx_to_char, start_text, prediction_len, temp)
#       9 inp = train[-1].view(-1, 1, 1)
#      11 for i in range(prediction_len):
# ---> 12     output, hidden = model(inp.to(device), hidden)
#      13     output_logits = output.cpu().data.view(-1)
#      14     p_next = F.softmax(output_logits / temp, dim=-1).detach().cpu().data.numpy()
#
# File e:\Programming\Python\PythonPacks\packsVenv\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[15], line 18, in TextRNN.forward(self, x, hidden)
#      16 def forward(self, x, hidden):
#      17     x = self.encoder(x).squeeze(2)
# ---> 18     out, (ht1, ct1) = self.lstm(x, hidden)
#      19     out = self.dropout(out)
#      20     x = self.fc(out)
#
# File e:\Programming\Python\PythonPacks\packsVenv\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File e:\Programming\Python\PythonPacks\packsVenv\lib\site-packages\torch\nn\modules\rnn.py:774, in LSTM.forward(self, input, hx)
#     772 self.check_forward_args(input, hx, batch_sizes)
#     773 if batch_sizes is None:
# --> 774     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     775                       self.dropout, self.training, self.bidirectional, self.batch_first)
#     776 else:
#     777     result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     778                       self.num_layers, self.dropout, self.training, self.bidirectional)
#
# KeyboardInterrupt:

# %%
model.eval()

print(evaluate(
    model, 
    char_to_idx, 
    idx_to_char, 
    temp=0.3, 
    prediction_len=1000, 
    start_text='кто на втором'
    )
)
# Out:
# кто на втором на севере вода и берега было бы в поляны в долину с обратно и поднялись на стойбищами и подняли свое странные полости и подножия подняли вода своей землянки, и на обратно на северо-привленных положение дальше с ними на севере и собаки поднялись в сторону и покрыто на север. Так как поднял за которой не стали стояли в несколько стояли на востоке и собаками и собаками пришлось высокой стены подняли поляны и последнего получить на обратно по глубины подняли по воде было воскликнул в образовали на севере которого воды по поляну и моря и после половина половину и последний в поляны и воды и совершенно поднялись по сторону, которые от нас по своей подняли на север, на развитица и уже на полосы по странными поднимались в землянки и стороны и подобные против с остальных положением в сторону с образом в делать и подножия вода в которой не обрыва и представляла море с оставили бы не было воды с только в своей стороны и вода высоких промежутки и подняли своим в сторону и на север, последней и вс
